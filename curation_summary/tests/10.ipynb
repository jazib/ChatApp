# %% [markdown]
# <a href="https://colab.research.google.com/github/jazib/ChatApp/blob/master/curation_summary/tests/10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install requirements

# %%
# !pip install langchain
# !pip install openai
# !pip install anthropic
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.0.235)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.5.14)
# Requirement already satisfied: langsmith<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.7)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.22.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.27.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1->langchain) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.27.8)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %%
from pydantic.main import BaseModel, Field
from langchain.chat_models import ChatOpenAI, ChatAnthropic
from langchain.output_parsers import ResponseSchema, StructuredOutputParser, PydanticOutputParser
from langchain.callbacks import get_openai_callback
from langchain.prompts import ChatPromptTemplate, PromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate, AIMessagePromptTemplate
from langchain.output_parsers import OutputFixingParser, PydanticOutputParser
import pandas as pd
from langchain.schema import HumanMessage, AIMessage

# %% [markdown]
# ### Set up LLMs

# %%
# Set Open AI Key
import os
import getpass
OPENAI_API_KEY = getpass.getpass("Enter OpenAI API Key")
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
# Out:
# Enter OpenAI API Key··········

# %%
# Set Anthropic AI Key
# import os
# import getpass
# ANTHROPIC_API_KEY = getpass.getpass("Enter Anthropic API Key")
# os.environ["ANTHROPIC_API_KEY"] = ANTHROPIC_API_KEY

# %%
# Initialize chat via OpenAI
chat = ChatOpenAI(temperature=0.0, model="gpt-3.5-turbo")

# Initialize chat via Anthropic
# chat = ChatAnthropic(temperature=0.0)

# %% [markdown]
# ### Set up prompts

# %%
# Set up prompt templates to pass to the LLM as a conversation
system_template = """\
You are a tech recruiter at a Silicon Valley technology startup. You are reviewing software developers for their fit at your company.

To assess whether a candidate should proceed or be rejected, use every one of the following assessment steps delimited by triple backticks below:

```
Evaluate a candidate based on the following criteria:

1. You only hire candidates who have work experience directly related to software application development. Specifically, you want candidates who could work in the following areas: [Frontend, Backend, Full Stack, DevOps, QA, Mobile, Data Science, Data Engineering, Data Analyst, or Engineering Lead]. If their most recent work history falls outside software development, reject them with the code "NOT_CORE_ROLE".

2. Infer which country the candidate comes from. In order to proceed in hiring, the candidate must come from one of the following approved countries [Canada, Mexico, Colombia, Chile, Costa Rica, Poland, Spain, Romania, Hungary]. You reject candidates from any other country. If the candidate is not from the right country, use the rejection code "OUTSIDE_GEO".

3. Infer the total years of experience the candidate has as a software developer. Calculate this by surveying all the items in their candidate_work_experiences and using just the jobs related to software engineering. Use the job's start_date in YYYY-MM-DD format to understand when they began each job. Many end_dates are missing, especially for current jobs, so be aware today's data is July 31, 2023. In order to proceed in hiring, the candidate must have 2 or more years of total hands-on software development experience. If the candidate does not have at least 2 years of experience, use the rejection code "TOO_JUNIOR".

4. Infer whether the candidate has Tech/Team Lead experience. You prefer candidates with tech or team lead experience over those without, but this is not a requirement just a nice-to-have.

5. Infer whether the candidate is an individual contributor or a manager. If the candidate is a senior manager and has been focused on management or executive roles for more than 3 years, use the rejection code "NOT_IC".

6. Infer the candidate's technology skills from both their set of skills and their job titles. In order for the candidate to proceed, they should work with modern tools and frameworks. If the candidate only works with old tools like C and Java, we are not interested in them and they should be rejected with the code "NOT_CORE_FOCUS".

7. You should never be analyzing communication skills for this candidate, that is not something to consider at this time.
```

A human will share a candidate with you to evaluate. Before you respond, fully evaluate the candidate using the criteria above. Come up with your answers for every step in order to create an entire mental image of this candidate from which you can evaluate the candidate as a whole.

Proceed in the following way:

```
1. Consider the candidate as a whole. How many years of experience do they have as a software developer? What has their career progression looked like? Have they leveled up quickly or slowly? Have they mostly worked as a developer or in other jobs?
2. Decide if you think we should proceed with them in the hiring process or reject them.
2. Share your decision in a structured format based on the formatting instructions provided as follows.
```

{format_instructions}
"""

human_training_template_1 = """\
Analyze the following candidate:

```
{
  "id": 640056,
  "country": "Colombia",
  "candidate_skills": [
    {
      "skill": {
        "name": "Python"
      }
    },
    {
      "skill": {
        "name": "JavaScript"
      }
    },
    {
      "skill": {
        "name": "Postgres"
      }
    },
    {
      "skill": {
        "name": "AWS"
      }
    },
    {
      "skill": {
        "name": "Docker"
      }
    },
    {
      "skill": {
        "name": "NoSQL"
      }
    },
    {
      "skill": {
        "name": "Git"
      }
    },
    {
      "skill": {
        "name": "Linux"
      }
    },
    {
      "skill": {
        "name": "Golang"
      }
    },
    {
      "skill": {
        "name": "API"
      }
    },
    {
      "skill": {
        "name": "Postman"
      }
    },
    {
      "skill": {
        "name": "Microservices"
      }
    },
    {
      "skill": {
        "name": "Firebase"
      }
    },
    {
      "skill": {
        "name": "CI/CD"
      }
    }
  ],
  "candidate_work_experiences": [
    {
      "job_title": "Software Developer",
      "start_date": "2017-07-01",
      "end_date": "2022-08-01"
    },
    {
      "job_title": "Software Developer",
      "start_date": "2022-09-01",
      "end_date": null
    }
  ],
  "candidate_educations": [
    {
      "degree": "Bachelors",
      "school_name": "Icesi",
      "start_year": 2017,
      "graduation_year": 2022
    }
  ]
}
```
"""

human_training_template_2 = """\
Analyze the following candidate:

```
{
  "id": 636699,
  "country": "Colombia",
  "candidate_skills": [
    {
      "skill": {
        "name": "Python"
      }
    },
    {
      "skill": {
        "name": "AWS"
      }
    },
    {
      "skill": {
        "name": "Java"
      }
    },
    {
      "skill": {
        "name": "Docker"
      }
    },
    {
      "skill": {
        "name": "Scala"
      }
    },
    {
      "skill": {
        "name": "API"
      }
    }
  ],
  "candidate_work_experiences": [
    {
      "job_title": "Full Stack Developer III and Team Lead, GDX Travel ",
      "start_date": "2017-07-01",
      "end_date": "2019-12-01"
    },
    {
      "job_title": "Software Engineering manager",
      "start_date": "2021-08-01",
      "end_date": "2023-06-01"
    },
    {
      "job_title": "Software Development Team Lead",
      "start_date": "2019-12-01",
      "end_date": "2021-08-01"
    }
  ],
  "candidate_educations": [
    {
      "degree": "Bachelors",
      "school_name": "Universidad Central de Colombia",
      "start_year": 2010,
      "graduation_year": 2016
    }
  ],
  "candidate_curation_workflows": [
    {
      "rejected_reason": null
    }
  ]
}
```
"""

ai_training_response_template_1 = """\
```
{
  "pass_": "Yes",
  "rejection_reason": "N/A",
  "summary": "- 6 years of work experience as a software developer.\\n  - Bachelor\'s degree in a relevant field.\\n  - Experience with modern skills: Python, JavaScript, Postgres, AWS, Docker, and Git.\\n  - Worked as a software developer in their most recent roles.\\n  - No tech lead experience.\\n  - No information available about their level of responsibility or career progression.",
  "level": "IC3",
  "score_experience": 72,
  "score_tech_lead": false,
  "score_modern_tech": "Many",
  "score_country": true
}
```
"""


ai_training_response_template_2 = """\
```
{
  "pass_": "Yes",
  "rejection_reason": "N/A",
  "summary": "Bachelor\'s degree in software engineering from a reputable university.\n  - Total of 6 years of experience as a software developer.\n  - Experience as a Full Stack Developer and Team Lead, demonstrating leadership skills.\n  - Experience with modern technologies such as Python, AWS, Docker, and Scala.\n  - From Colombia, which is one of the approved countries.\n  - Experience as a tech lead is not explicitly mentioned.\n  - Experience with Java may indicate a focus on older technologies.\n  - Recent experience as a manager may suggest a shift away from individual contributor roles.\n  - Experience with C and Java may indicate a lack of experience with modern tools and frameworks.\n",
  "level": "IC4",
  "score_experience": 72,
  "score_tech_lead": true,
  "score_modern_tech": "Some",
  "score_country": true
}
```
"""

human_template = """\
Analyze the following candidate:

```
{candidate}
```
"""

# %%
# Set up desired response structure to be returned by the LLM
from pydantic.main import BaseModel, Field
from langchain.output_parsers import OutputFixingParser, PydanticOutputParser

class CandidateCurationSummaryModel(BaseModel):
    pass_: str = Field(
        description="Based on your analysis, should we proceed this candidate? Answer Yes if yes, No if not, or Needs More Information if you do not have enough information."
    )
    rejection_reason: str = Field(
        description="If you decided not to proceed with this candidate, share the code for your rejection. Otherwise, respond 'N/A'."
    )
    summary: str = Field(
        description="In under 150 words, list the good and bad things about this candidate in bullet points. This should capture your thoughts on why we should proceed with or reject this candidate."
    )
    level: str = Field(
        description="Based on your analysis, what do you determie the candidate's software engineering level on the Individual Contributor scale (from IC1 to IC6, with IC1 being Intern-level, IC2 Junior-level, IC3 Career-level, IC4 Advanced-level, IC5 Expert-level, and IC6 being Principal-level)? Provide an answer between IC1 and IC6, or if you did not have an answer respond 'N/A'."
    )
    score_experience: int = Field(
        description="How many months of work experience as a software developer does this candidate have? Make sure to include their current work up to today's date, which is August 3, 2023. Answer in an integer. If you think the answer is 'N/A', return 0 instead."
    )
    score_tech_lead: bool = Field(
        description="Does this candidate have any experience as a tech/team lead? Answer True or False. If this information is not available, answer False."
    )
    score_modern_tech: str = Field(
        description="Does this candidate have experience working with any of the following skills: [Ruby, Django, AWS, Typescript, Docker, Node, React, JQuery, Python, Angular, .NET, Java]? Answer Many if they have 3 or more, Some with 1-3 of these skills, and None if they have 0 of these skills. Answer None if you are unsure."
    )
    score_country: bool = Field(
        description="Is this candidate from one of the valid countries we hire from? Answer True or False."
    )

parser = PydanticOutputParser(pydantic_object=CandidateCurationSummaryModel)
fix_format_parser = OutputFixingParser.from_llm(parser=parser, llm=chat)

# Format the response instructions to pass into the templates
format_instructions = fix_format_parser.get_format_instructions()

# %%
# Generate the formatted chat conversation to pass to the LLM using the templates and response structure

# Generate the messages from templates
system_prompt = PromptTemplate(
    template=system_template,
    input_variables=[],
    partial_variables={"format_instructions": format_instructions},
)
system_message = SystemMessagePromptTemplate(prompt=system_prompt)


human_prompt = PromptTemplate(
    template=human_template,
    input_variables=["candidate"]
)
human_message = HumanMessagePromptTemplate(prompt=human_prompt)

chat_prompt = ChatPromptTemplate.from_messages([system_message, human_message])

# %% [markdown]
# ### Run the test for many *candidates*

# %%
def get_candidate_summary(candidate):
  # Run the test
  messages = chat_prompt.format_prompt(candidate=candidate, format_instructions=format_instructions).to_messages()
  # Request the response and print API usage
  with get_openai_callback() as cb:
      response = chat(messages)
      return response, cb

# %%
# Set up a list of candidates candidates
# Candidates for this test should have work experience, skills, and education
# Drop in the query you use here so we can reference it and modify it
def read_data_from_json_file(file_name):
  import json
  file_path = f"/content/sample_data/{file_name}"

  try:
      with open(file_path, 'r') as file:
          data = json.load(file)
          return data
  except FileNotFoundError:
      print("File not found or path is incorrect.")
  except json.JSONDecodeError:
      print("Error decoding JSON data.")

# %%
# Create a candidate score using inferred data about the candidate
def generate_score(candidate_res: dict) -> float:
    try:
        value = 5
        ai_level = candidate_res["ai_level"]
        ai_score_experience = candidate_res["ai_score_experience"]
        ai_score_tech_lead = candidate_res["ai_score_tech_lead"]
        ai_score_modern_tech = candidate_res["ai_score_modern_tech"]
        ai_score_country = candidate_res["ai_score_country"]

        if ai_level == "IC1":
            value *= 0.1
        elif ai_level == "IC2":
            value *= 0.5
        elif ai_level == "IC4":
            value *= 1.3
        elif ai_level == "IC5":
            value *= 2
        elif ai_level == "IC6":
            value *= 2.5

        value *= max(0, min(2.5, ai_score_experience / 24))

        if ai_score_tech_lead:
            value *= 2

        if ai_score_modern_tech == "Many":
            value *= 2
        elif ai_score_modern_tech == "Some":
            value *= 1.5
        elif ai_score_modern_tech == "None":
            value *= 0.8

        if not ai_score_country:
            value *= 0.1

        return round(value, 1)
    except KeyError:
        print("Error: Missing or unexpected value in candidate_res dictionary.")
        return None

# %%
# Filter candidates based on data - we are only interested in candidates that
# have education, skills and work history
def process_candidates(candidates):
  total_tokens = 0
  total_cost = 0
  total_passes = 0
  total_passing_score = 0
  total_fails = 0
  total_failing_score = 0
  total_unknowns = 0
  candidate_results = []
  for candidate in candidates:
    candidate_res = {"candidate_id": candidate["id"]}
    rejected_reasons = [r["rejected_reason"] for r in candidate["candidate_curation_workflows"] if r["rejected_reason"] != None]
    candidate_res["rejected_reasons"] = rejected_reasons

    # Make sure we're not sending candidate_curation_workflows to AI
    sanitized_candidate = {key: value for key, value in candidate.items() if key != "candidate_curation_workflows"}
    res, cb = get_candidate_summary(sanitized_candidate)
    print(res)

    # Notice we're using fix_format parser to get exact output defined above
    dict_res = fix_format_parser.parse(res.content).dict()

    ai_pass = dict_res["pass_"]
    candidate_res["ai_pass"] = ai_pass
    candidate_res["ai_rejection_reason"] = dict_res["rejection_reason"]
    candidate_res["ai_level"] = dict_res["level"]
    candidate_res["ai_score_experience"] = dict_res["score_experience"]
    candidate_res["ai_score_tech_lead"] = dict_res["score_tech_lead"]
    candidate_res["ai_score_modern_tech"] = dict_res["score_modern_tech"]
    candidate_res["ai_score_country"] = dict_res["score_country"]
    candidate_res["ai_summary"] = dict_res["summary"]

    ai_score = generate_score(candidate_res)
    candidate_res["ai_score"] = ai_score

    candidate_results.append(candidate_res)
    total_tokens += cb.total_tokens
    total_cost += cb.total_cost
    if ai_pass == "Yes":
      total_passes+=1
    elif ai_pass == "No":
      total_fails+=1
    else:
      total_unknowns+=1

    if ai_score >= 3:
        total_passing_score+= 1
    elif ai_score <3:
        total_failing_score+= 1

  return {
      "candidate_results": candidate_results,
      "total_passes": total_passes,
      "total_fails": total_fails,
      "total_passing_score": total_passing_score,
      "total_failing_score": total_failing_score,
      "total_unknowns": total_unknowns,
      "total_cost": total_cost,
      "total_tokens": total_tokens
  }

# %%
def print_results(cand_results, total_candidates, is_pass):
  total_passes = cand_results["total_passes"]
  total_fails = cand_results["total_fails"]
  print(f"Total AI Passes: {total_passes}")
  print(f"Total AI Fails: {total_fails}")
  print(f"Total AI Unknowns: {cand_results['total_unknowns']}")
  total_correct = total_passes if is_pass else total_fails
  print(f"Percentage AI accuracy: {total_correct/total_candidates * 100} %")

  print("\nTest Results - Scored Approach")
  total_passing_score = cand_results["total_passing_score"]
  total_failing_score = cand_results["total_failing_score"]
  print(f"Total AI Passing Scores: {total_passing_score}")
  print(f"Total AI Failing Scores: {total_failing_score}")
  print(f"Total AI Unknowns: {cand_results['total_unknowns']}")
  total_correct_combined = total_passing_score if is_pass else total_failing_score
  print(f"Percentage AI accuracy combined: {total_correct_combined/total_candidates * 100} %")

  print("\nTest API Consumption")
  print(f"Number of tokens used for the test: {cand_results['total_tokens']} ")
  print(f"Cost for the test: {cand_results['total_cost']} USD")
  print("\nRaw Data")
  print("\n".join(str(generate_score(item)) + " " + str(item) for item in cand_results["candidate_results"]))

  df = pd.DataFrame(cand_results["candidate_results"])
  display(df)

# %% [markdown]
# # Run the test here

# %%
# DON'T RUN THIS BLOCK
# IT IS JUST A REFERENCE TO THE GRAPHQL QUERY TO GENERATE CANDIDATE LISTS

# Passed Candidates Query. Simply run this in hasura console and copy paste the results
# in the file: sample_data/passed_candidates.json
query GetPassedCandidates {
  candidate(
    limit: 20
    order_by: {created_at: desc}
    where: {
    candidate_work_experiences: {id: {_is_null: false}}
    candidate_educations: {id: {_is_null: false}}
    candidate_skills: {id: {_is_null: false}}
     furthest_candidate_curation_workflow: {status: {_in: [
          ACCEPTED,
          PHONE_SCREEN_PASSED,
          PHONE_SCREEN_PASSED,
          PHONE_SCREEN_NO_SHOW
          PHONE_SCREEN_COMPLETED
          PHONE_SCREEN_SCHEDULED
          PHONE_SCREEN_SCHEDULING
        ]}
      }
    }

  ) {
    id
    country
    candidate_skills {
      skill {
        name
      }
    }
    candidate_work_experiences {
      job_title
      start_date
      end_date
    }
    candidate_educations {
      degree
      school_name
      start_year
      graduation_year
    }
    candidate_curation_workflows {
      rejected_reason
    }
  }
}


# Failed Candidates Query. Simply run this in hasura console and copy paste the results
# in the file: sample_data/failed_candidates.json
query GetFailedCandidates {
  candidate(
    limit: 20
    order_by: {created_at: desc}
    where: {
    candidate_work_experiences: {id: {_is_null: false}}
    candidate_educations: {id: {_is_null: false}}
    candidate_skills: {id: {_is_null: false}}
      candidate_curation_workflows: {rejected_reason: {_nin: [WORK_AUTHORIZATION, VALUABLE_PROFILE, TIMING]}}
     furthest_candidate_curation_workflow: {status: {_nin: [
          ACCEPTED,
          PHONE_SCREEN_PASSED,
          PHONE_SCREEN_PASSED,
          PHONE_SCREEN_NO_SHOW,
          PHONE_SCREEN_COMPLETED,
          PHONE_SCREEN_SCHEDULED,
          PHONE_SCREEN_SCHEDULING,
      		NEW_NEEDS_REVIEW
        ]}
      }
    }

  ) {
    id
    country
    candidate_skills {
      skill {
        name
      }
    }
    candidate_work_experiences {
      job_title
      start_date
      end_date
    }
    candidate_educations {
      degree
      school_name
      start_year
      graduation_year
    }
    candidate_curation_workflows {
      rejected_reason
    }
  }
}

# %%
print("Running test for 'passed' candidates...")
p_cands = read_data_from_json_file("passed_candidates.json")["data"]["candidate"]
total_p_cands = len(p_cands)
p_cand_results = process_candidates(p_cands)
print_results(p_cand_results, total_p_cands, True)
# Out:
# Running test for 'passed' candidates...
# content='1. The candidate has a total of 13 years of experience as a software developer. Their career progression has been as follows:\n   - Founding Product Engineer (2020-present)\n   - Staff Engineer (2019-2020)\n   - Senior Engineer (2016-2019)\n   - Developer (2010-2016)\n\n   The candidate has leveled up relatively quickly, starting as a developer and progressing to senior and staff engineer roles. They have primarily worked as a developer throughout their career.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "Good things about this candidate:\\n- Has 13 years of experience as a software developer\\n- Has progressed quickly in their career\\n- Has experience in frontend development using React and Typescript\\n- Has experience with modern tools and frameworks\\n\\nLevel: IC4",\n  "level": "IC4",\n  "score_experience": 156,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has 2 years and 7 months of experience as a software developer. They started as a Software Specialist in January 2018 and then became a Software Engineer in December 2020. Their career progression has been relatively steady, with a promotion to a higher-level role after about 2 years. They have primarily worked as a developer.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has relevant work experience in software development and has progressed in their career.\\n- Good: They have a Master\'s degree in a related field.\\n- Good: The candidate has experience with modern technologies such as AWS, Java, Kubernetes, Scala, Spring, and Node.js.\\n- Good: They have worked with microservices and have experience in data analysis.\\n- Good: The candidate is from Canada, which is one of the approved countries.\\n- Bad: The candidate\'s experience as a software developer is relatively junior.\\n- Bad: There is no indication of tech/team lead experience.\\n- Bad: The candidate\'s work experience does not include any specific role related to data science or engineering.\\n- Bad: The candidate\'s work experience does not include any specific role related to QA or mobile development.",\n  "level": "IC2",\n  "score_experience": 31,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has two work experiences related to software development. They started as a Backend Developer from September 2019 to March 2021, and then transitioned to a Software Engineer role from March 2021 to the present. Their career progression shows a transition from a more specialized role to a broader software engineering role.\n\n2. The candidate is from Colombia, which is one of the approved countries for hiring.\n\n3. Based on the start dates of their software development roles, the candidate has a total of 4 years of experience as a software developer. They have met the requirement of having at least 2 years of experience.\n\n4. There is no information provided about the candidate having Tech/Team Lead experience.\n\n5. There is no information provided about the candidate being a manager or senior manager.\n\n6. The candidate has experience with modern tools and frameworks such as JavaScript, TypeScript, Java, Kubernetes, Scala, Kotlin, Kafka, Spring, MongoDB, GraphQL, GitHub, RabbitMQ, Prometheus, and SpringBoot. They have worked with a variety of technologies commonly used in software development.\n\nBased on the evaluation, we should proceed with this candidate in the hiring process.\n\n```json\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 4 years of experience as a software developer.\\n- They have a good mix of specialized and broader software engineering roles.\\n- The candidate is from an approved country for hiring.\\n- They have experience with modern tools and frameworks.",\n  "level": "IC3",\n  "score_experience": 48,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has a total of 9 years of work experience as a software developer. They have progressed from a Frontend Developer to a Senior Frontend Developer and then to a Senior Software Engineer. They have primarily worked as a developer throughout their career.\n\n2. Based on the criteria:\n\n- The candidate has work experience directly related to software application development, specifically in the Frontend area. They have worked as a Frontend Developer and Senior Frontend Developer.\n- The candidate is from Romania, which is one of the approved countries.\n- The candidate has more than 2 years of total hands-on software development experience.\n- There is no information provided about the candidate having Tech/Team Lead experience.\n- The candidate is not a senior manager focused on management or executive roles.\n- The candidate has experience with modern tools and frameworks like React, JavaScript, Typescript, Redux, Git, HTML, CSS, and API.\n\n3. Based on the evaluation, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 9 years of work experience as a software developer.\\n- They have progressed from a Frontend Developer to a Senior Frontend Developer and then to a Senior Software Engineer.\\n- They have primarily worked as a developer throughout their career.\\n- The candidate is from Romania, which is one of the approved countries.\\n- They have more than 2 years of total hands-on software development experience.\\n- The candidate has experience with modern tools and frameworks like React, JavaScript, Typescript, Redux, Git, HTML, CSS, and API.",\n  "level": "IC4",\n  "score_experience": 108,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has two years of work experience as a software developer. They have held the position of Senior Software Engineer in their most recent roles. Their career progression appears to be steady, with no gaps in their work history. They have primarily worked as a developer.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: Two years of work experience as a software developer\\n- Good: Steady career progression\\n- Good: Strong skills in Python, React, JavaScript, AWS, SQL, Typescript, Java, Docker, MySQL, NoSQL, Angular, Django, and HTML\\n- Good: Relevant education background\\n- Bad: None",\n  "level": "IC3",\n  "score_experience": 24,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has been working as a Senior Software Developer since January 2018. They have a Bachelor\'s degree from Universidad de Costa Rica, which they obtained in 2019. It appears that they have been working primarily as a developer.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has relevant work experience as a Senior Software Developer.\\n- Good: They have a strong skill set, including React, JavaScript, AWS, Node, Typescript, and Java.\\n- Good: The candidate has a Bachelor\'s degree.\\n- Good: They are from Costa Rica, which is one of the approved countries.\\n- Bad: There is no information about their total years of experience.\\n- Bad: It is unclear if they have any tech/team lead experience.\\n- Bad: It is unclear if they have experience with modern tools and frameworks.",\n  "level": "N/A",\n  "score_experience": null,\n  "score_tech_lead": null,\n  "score_modern_tech": null,\n  "score_country": null\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 4 years of experience as a software developer. They have worked as a backend developer since October 2018, with their most recent position starting in May 2021. Their career progression has been focused on backend development, with no experience in other roles.\n\n2. Based on the criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 4 years of experience as a software developer\\n- They have a strong focus on backend development\\n- They have experience with modern technologies like Postgres, AWS, Node, and Typescript\\n- The candidate is from Colombia, which is one of the approved countries\\n- Overall, the candidate meets the criteria and should proceed in the hiring process",\n  "level": "IC3",\n  "score_experience": 48,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 19 years of work experience as a software developer. Their career progression has been steady, starting as a Web Developer/IT Support and progressing to Software Developer II, Software Engineer, Senior Java Web Developer, and finally Senior Software Developer. They have mostly worked as a developer, with a focus on web development and software engineering.\n\n2. Based on the criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has 19 years of work experience as a software developer.\\n- Good: They have a strong background in web development and software engineering.\\n- Good: The candidate has experience with PHP, SQL, Java, Angular, Kubernetes, CSS, Golang, and API.\\n- Good: They have a Bachelor\'s degree and a Master\'s degree.\\n- Good: The candidate is from Canada, which is one of the approved countries.\\n- Needs Improvement: It is unclear if the candidate has tech/team lead experience.\\n- Needs Improvement: It is unclear if the candidate has experience with modern tools and frameworks.\\n- Needs Improvement: The candidate\'s most recent work history is as a Software Developer II, which may not align with the desired roles of Frontend, Backend, Full Stack, DevOps, QA, Mobile, Data Science, Data Engineering, Data Analyst, or Engineering Lead.",\n  "level": "N/A",\n  "score_experience": 228,\n  "score_tech_lead": null,\n  "score_modern_tech": "N/A",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 8 years of work experience as a software developer. Their career progression has been steady, starting as a Web Developer and progressing to Front end Developer, Senior Front end Developer, Front end Tech Lead, Full Stack Developer, and finally Senior Software Consultant. They have primarily worked as a developer, with a focus on front end development.\n\n2. Based on the criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: 8 years of software development experience, steady career progression\\n- Good: Experience in front end development and tech lead role\\n- Good: Strong skills in Python, React, JavaScript, AWS, Node, Typescript, Docker, Django\\n- Good: Relevant education in computer science\\n- Bad: No experience as a tech/team lead\\n- Bad: Limited experience with modern tools like Ruby on Rails, Next.js, D3.js\\n- Bad: No experience in backend or data engineering roles",\n  "level": "IC4",\n  "score_experience": 96,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 4 years and 9 months of experience as a software developer. They have worked as a back-end developer in their previous roles, with their most recent role starting in January 2022 and ending in July 2023. They have progressed steadily in their career, with each role building upon their previous experience. They hold a Bachelor\'s degree from Universidad Tecnologica de Pereira, which they obtained in 2023.\n\n2. Based on the evaluation criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "Good things about this candidate:\\n- Has 4+ years of experience as a software developer\\n- Worked as a back-end developer in previous roles\\n- Holds a Bachelor\'s degree\\n\\nLevel: IC3",\n  "level": "IC3",\n  "score_experience": 57,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 8 years of work experience as a software developer. Their career progression has been steady, starting as an intern and progressing to backend developer, full-stack developer, and senior software engineer roles. They have experience working in both small and large companies.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has 8 years of work experience as a software developer.\\n- Good: They have experience with modern technologies such as Python, React, JavaScript, and Node.\\n- Good: The candidate has worked in various software engineering roles, demonstrating their versatility.\\n- Good: They have a bachelor\'s degree in computer science.\\n- Good: The candidate is from Mexico, which is one of the approved countries.\\n- Bad: No tech/team lead experience mentioned.\\n- Bad: The candidate\'s education is unfinished.",\n  "level": "IC4",\n  "score_experience": 96,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 13 years of work experience as a software developer. Their career progression has been steady, with a mix of freelance and full-time positions. They have worked as a Frontend Web Developer Freelance, Web UI Developer, Frontend Developer, Development Lead, and Web Developer.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has 13 years of work experience as a software developer.\\n- Good: They have experience with modern technologies like React, JavaScript, HTML, API, GitHub, and CI/CD.\\n- Good: The candidate has held various frontend development roles, showing their expertise in this area.\\n- Good: They have experience as a Development Lead, indicating potential leadership skills.\\n- Good: The candidate is from Colombia, which is one of the approved countries.\\n- Bad: The candidate\'s education is listed as \'Other\' and does not provide specific details.\\n- Bad: The candidate\'s work experience includes some gaps between positions.\\n- Bad: The candidate\'s work experience does not include any backend or full-stack development roles.",\n  "level": "IC3",\n  "score_experience": 156,\n  "score_tech_lead": true,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 11 years of work experience as a software developer. Their career progression has been as follows:\n   - Integration Specialist (2012-2013)\n   - Technical Lead (2013-2016)\n   - Team Lead Scrum Master (2016-2018)\n   - Application Architect Web Development (2018-2021)\n   - Technical Manager (2021-2022)\n\n   The candidate has leveled up steadily throughout their career, starting as an Integration Specialist and progressing to higher-level roles such as Technical Lead, Team Lead Scrum Master, Application Architect Web Development, and finally Technical Manager. They have primarily worked as a developer and have also gained experience in leadership and management roles.\n\n2. Based on the evaluation criteria, we should proceed with this candidate in the hiring process.\n\n**Decision:** Yes\n\n**Rejection Reason:** N/A\n\n**Summary:**\n- The candidate has 11 years of experience as a software developer.\n- They have shown steady career progression and have experience in both development and leadership roles.\n- The candidate has a strong skill set, including Python, React, Postgres, AWS, SQL, and more.\n- They have a Masters and Bachelors degree from Lakehead University.\n- Overall, the candidate appears to be a strong fit for our software development team.\n\n**Level:** IC4 (Advanced-level)\n\n**Score Experience:** 132 (11 years)\n\n**Score Tech Lead:** True\n\n**Score Modern Tech:** Many\n\n**Score Country:** True\n\n```json\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "The candidate has 11 years of experience as a software developer. They have shown steady career progression and have experience in both development and leadership roles. The candidate has a strong skill set, including Python, React, Postgres, AWS, SQL, and more. They have a Masters and Bachelors degree from Lakehead University. Overall, the candidate appears to be a strong fit for our software development team.",\n  "level": "IC4",\n  "score_experience": 132,\n  "score_tech_lead": true,\n  "score_modern_tech": "Many",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has a total of 2 years and 8 months of work experience as a software developer. Their career progression includes roles such as L2 Support Engineer, Global Development Director, Software Engineer, and Project Manager. They have mostly worked as a developer, with some experience in management.\n\n2. Based on the evaluation criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good experience with modern technologies like React, JavaScript, Typescript, SQL, and Git\\n- Has a total of 2 years and 8 months of software development experience\\n- Career progression includes roles as a Software Engineer and Global Development Director\\n- Some experience in management\\n- Holds degrees from reputable universities\\n- From an approved country (Colombia)",\n  "level": "IC3",\n  "score_experience": 32,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content="1. The candidate has primarily worked in product design and product management roles, with some experience as a visual designer. They have held positions such as Sr Product Designer, Visual Designer, Product Lead, and Head of Product. Their career progression has been steady, starting as a Head of Product in 2016 and progressing to a Sr Product Designer role in 2023. They have a Bachelor's degree in a relevant field from Pontifica Universidad Javeriana.\n\n2. Based on the criteria provided, we should reject this candidate. Their work experience is not directly related to software application development, as they have primarily worked in product design and management roles. Therefore, they do not meet the requirement for a core software development role.\n\n**Decision:**\n- Pass: No\n- Rejection Reason: NOT_CORE_ROLE\n- Summary: \n  - Good: Relevant education and experience in product design and management.\n  - Bad: Lack of work experience directly related to software application development.\n- Level: N/A\n- Score Experience: N/A\n- Score Tech Lead: N/A\n- Score Modern Tech: N/A\n- Score Country: True" additional_kwargs={} example=False
# content='1. The candidate has a total of 13 years of work experience as a software developer. They started their career as a Software Engineer in 2010 and have since held various software development roles. They have also worked as a Software Engineer/Tech Leader from 2015 to 2021, indicating some experience in a leadership role. Their career progression seems steady, with a mix of individual contributor and leadership roles.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good amount of experience as a software developer\\n- Has experience in both individual contributor and leadership roles\\n- Familiarity with modern technologies like React, JavaScript, Typescript, Docker, and .NET\\n- Strong educational background with a Bachelor\'s degree\\n- From an approved country (Mexico)",\n  "level": "IC4",\n  "score_experience": 156,\n  "score_tech_lead": true,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 6 years of experience as a software developer. They have worked as a software developer since July 2017, with their most recent job ending in August 2022. Their career progression shows that they have been consistently working as a developer.\n\n2. Based on the criteria, the candidate meets the requirement of having work experience directly related to software application development. They have worked as a software developer in their most recent roles.\n\n3. The candidate is from Colombia, which is one of the approved countries for hiring.\n\n4. The candidate has a total of 6 years of experience as a software developer, which exceeds the minimum requirement of 2 years.\n\n5. There is no information provided about the candidate having Tech/Team Lead experience.\n\n6. The candidate has experience with modern tools and frameworks such as Python, JavaScript, Postgres, AWS, Docker, NoSQL, Git, and CI/CD. They also have experience with microservices and API development.\n\nBased on the evaluation, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 6 years of experience as a software developer\\n- They have consistently worked as a developer\\n- They have experience with modern tools and frameworks\\n- The candidate is from an approved country\\n- No information provided about Tech/Team Lead experience",\n  "level": "IC3",\n  "score_experience": 72,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 7 years and 6 months of work experience as a software developer. They have held positions such as Senior Developer Architect, Analyst programmer, and Lead Software Developer. Their career progression has been steady, starting as an Analyst programmer and eventually moving up to a Lead Software Developer role. They have mostly worked as a developer, with some experience in architecture and leadership roles.\n\n2. Based on the evaluation criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has 7+ years of software development experience and has held positions as a Senior Developer Architect and Lead Software Developer.\\n- Good: They have experience with modern technologies such as Python, React, JavaScript, AWS, and Angular.\\n- Good: The candidate has a strong educational background, including attending Harvard University.\\n- Bad: The candidate\'s work experience is not exclusively focused on software development.\\n- Bad: The candidate\'s education does not include a degree in a relevant field.",\n  "level": "IC4",\n  "score_experience": 90,\n  "score_tech_lead": true,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 8 years of work experience as a software developer. Their career progression has been as follows:\n   - Software Development Engineer (2020-01-01 to 2022-12-31)\n   - Frontend Developer (2018-01-01 to 2020-12-31)\n   - Javascript Full Stack Developer (2018-01-01 to 2020-12-31)\n   - Web developer (2015-01-01 to 2018-12-31)\n   - Software Engineer (2022-10-01 to present)\n\n   The candidate has leveled up relatively quickly, with a transition from web developer to frontend developer and then to full stack developer. They have mostly worked as a developer throughout their career.\n\n2. Based on the evaluation criteria, we should proceed with this candidate in the hiring process.\n\n**Decision:** Yes\n\n**Rejection Reason:** N/A\n\n**Summary:**\n- The candidate has 8 years of experience as a software developer.\n- They have experience with modern technologies such as React, JavaScript, AngularJS, and Git.\n- The candidate has a diverse background, having worked in various software development roles.\n- They have a degree from Universidad Católica.\n- The candidate is from Spain, which is one of the approved countries.\n\n**Level:** IC4 (Advanced-level)\n\n**Score Experience:** 96 months\n\n**Score Tech Lead:** False\n\n**Score Modern Tech:** Some\n\n**Score Country:** True' additional_kwargs={} example=False
# content='1. The candidate has been working as a Frontend Developer since September 2021. They have a Master\'s degree in 2018, a Bootcamp in 2022, and a Bachelor\'s degree in 2016. Their career progression shows a focus on frontend development, with a recent educational background in software development.\n\n2. Based on the criteria:\n   - The candidate has work experience directly related to software application development as a Frontend Developer, so they meet the first criteria.\n   - The candidate is from Colombia, which is one of the approved countries, so they meet the second criteria.\n   - The candidate has less than 2 years of total hands-on software development experience, as their only relevant work experience is since September 2021. Therefore, they do not meet the third criteria.\n   - There is no information provided about the candidate\'s tech/team lead experience, so we cannot determine if they meet the fourth criteria.\n   - There is no information provided about the candidate\'s management experience, so we cannot determine if they meet the fifth criteria.\n   - The candidate has experience with modern frontend technologies like React, JavaScript, Typescript, Git, and HTML, so they meet the sixth criteria.\n\n3. Based on the evaluation, we should reject this candidate because they do not meet the third criteria of having at least 2 years of total hands-on software development experience.\n\n{\n  "pass_": "No",\n  "rejection_reason": "TOO_JUNIOR",\n  "summary": "- The candidate has work experience as a Frontend Developer\\n- The candidate is from Colombia\\n- The candidate has less than 2 years of total hands-on software development experience\\n- No information provided about tech/team lead or management experience\\n- The candidate has experience with modern frontend technologies",\n  "level": "N/A",\n  "score_experience": 10,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# Total AI Passes: 18
# Total AI Fails: 2
# Total AI Unknowns: 0
# Percentage AI accuracy: 90.0 %
#
# Test Results - Scored Approach
# Total AI Passing Scores: 18
# Total AI Failing Scores: 2
# Total AI Unknowns: 0
# Percentage AI accuracy combined: 90.0 %
#
# Test API Consumption
# Number of tokens used for the test: 40098
# Cost for the test: 0.063072 USD
#
# Raw Data
# 32.5 {'candidate_id': 650789, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 156, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': 'Good things about this candidate:\n- Has 13 years of experience as a software developer\n- Has progressed quickly in their career\n- Has experience in frontend development using React and Typescript\n- Has experience with modern tools and frameworks\n\nLevel: IC4', 'ai_score': 32.5}
# 6.5 {'candidate_id': 650124, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC2', 'ai_score_experience': 31, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has relevant work experience in software development and has progressed in their career.\n- Good: They have a Master's degree in a related field.\n- Good: The candidate has experience with modern technologies such as AWS, Java, Kubernetes, Scala, Spring, and Node.js.\n- Good: They have worked with microservices and have experience in data analysis.\n- Good: The candidate is from Canada, which is one of the approved countries.\n- Bad: The candidate's experience as a software developer is relatively junior.\n- Bad: There is no indication of tech/team lead experience.\n- Bad: The candidate's work experience does not include any specific role related to data science or engineering.\n- Bad: The candidate's work experience does not include any specific role related to QA or mobile development.", 'ai_score': 6.5}
# 20.0 {'candidate_id': 649626, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 48, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has 4 years of experience as a software developer.\n- They have a good mix of specialized and broader software engineering roles.\n- The candidate is from an approved country for hiring.\n- They have experience with modern tools and frameworks.', 'ai_score': 20.0}
# 32.5 {'candidate_id': 648288, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 108, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has 9 years of work experience as a software developer.\n- They have progressed from a Frontend Developer to a Senior Frontend Developer and then to a Senior Software Engineer.\n- They have primarily worked as a developer throughout their career.\n- The candidate is from Romania, which is one of the approved countries.\n- They have more than 2 years of total hands-on software development experience.\n- The candidate has experience with modern tools and frameworks like React, JavaScript, Typescript, Redux, Git, HTML, CSS, and API.', 'ai_score': 32.5}
# 10.0 {'candidate_id': 648034, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 24, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- Good: Two years of work experience as a software developer\n- Good: Steady career progression\n- Good: Strong skills in Python, React, JavaScript, AWS, SQL, Typescript, Java, Docker, MySQL, NoSQL, Angular, Django, and HTML\n- Good: Relevant education background\n- Bad: None', 'ai_score': 10.0}
# 0.0 {'candidate_id': 647493, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 0, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'None', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has relevant work experience as a Senior Software Developer.\n- Good: They have a strong skill set, including React, JavaScript, AWS, Node, Typescript, and Java.\n- Good: The candidate has a Bachelor's degree.\n- Good: They are from Costa Rica, which is one of the approved countries.\n- Bad: There is no information about their total years of experience.\n- Bad: It is unclear if they have any tech/team lead experience.\n- Bad: It is unclear if they have experience with modern tools and frameworks.", 'ai_score': 0.0}
# 20.0 {'candidate_id': 647124, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 48, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has 4 years of experience as a software developer\n- They have a strong focus on backend development\n- They have experience with modern technologies like Postgres, AWS, Node, and Typescript\n- The candidate is from Colombia, which is one of the approved countries\n- Overall, the candidate meets the criteria and should proceed in the hiring process', 'ai_score': 20.0}
# 18.8 {'candidate_id': 645953, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 228, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has 19 years of work experience as a software developer.\n- Good: They have a strong background in web development and software engineering.\n- Good: The candidate has experience with PHP, SQL, Java, Angular, Kubernetes, CSS, Golang, and API.\n- Good: They have a Bachelor's degree and a Master's degree.\n- Good: The candidate is from Canada, which is one of the approved countries.\n- Needs Improvement: It is unclear if the candidate has tech/team lead experience.\n- Needs Improvement: It is unclear if the candidate has experience with modern tools and frameworks.\n- Needs Improvement: The candidate's most recent work history is as a Software Developer II, which may not align with the desired roles of Frontend, Backend, Full Stack, DevOps, QA, Mobile, Data Science, Data Engineering, Data Analyst, or Engineering Lead.", 'ai_score': 18.8}
# 24.4 {'candidate_id': 644944, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 96, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': '- Good: 8 years of software development experience, steady career progression\n- Good: Experience in front end development and tech lead role\n- Good: Strong skills in Python, React, JavaScript, AWS, Node, Typescript, Docker, Django\n- Good: Relevant education in computer science\n- Bad: No experience as a tech/team lead\n- Bad: Limited experience with modern tools like Ruby on Rails, Next.js, D3.js\n- Bad: No experience in backend or data engineering roles', 'ai_score': 24.4}
# 23.8 {'candidate_id': 644860, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 57, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "Good things about this candidate:\n- Has 4+ years of experience as a software developer\n- Worked as a back-end developer in previous roles\n- Holds a Bachelor's degree\n\nLevel: IC3", 'ai_score': 23.8}
# 32.5 {'candidate_id': 644735, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 96, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has 8 years of work experience as a software developer.\n- Good: They have experience with modern technologies such as Python, React, JavaScript, and Node.\n- Good: The candidate has worked in various software engineering roles, demonstrating their versatility.\n- Good: They have a bachelor's degree in computer science.\n- Good: The candidate is from Mexico, which is one of the approved countries.\n- Bad: No tech/team lead experience mentioned.\n- Bad: The candidate's education is unfinished.", 'ai_score': 32.5}
# 50.0 {'candidate_id': 644633, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 156, 'ai_score_tech_lead': True, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has 13 years of work experience as a software developer.\n- Good: They have experience with modern technologies like React, JavaScript, HTML, API, GitHub, and CI/CD.\n- Good: The candidate has held various frontend development roles, showing their expertise in this area.\n- Good: They have experience as a Development Lead, indicating potential leadership skills.\n- Good: The candidate is from Colombia, which is one of the approved countries.\n- Bad: The candidate's education is listed as 'Other' and does not provide specific details.\n- Bad: The candidate's work experience includes some gaps between positions.\n- Bad: The candidate's work experience does not include any backend or full-stack development roles.", 'ai_score': 50.0}
# 65.0 {'candidate_id': 644548, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 132, 'ai_score_tech_lead': True, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': 'The candidate has 11 years of experience as a software developer. They have shown steady career progression and have experience in both development and leadership roles. The candidate has a strong skill set, including Python, React, Postgres, AWS, SQL, and more. They have a Masters and Bachelors degree from Lakehead University. Overall, the candidate appears to be a strong fit for our software development team.', 'ai_score': 65.0}
# 13.3 {'candidate_id': 643589, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 32, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- Good experience with modern technologies like React, JavaScript, Typescript, SQL, and Git\n- Has a total of 2 years and 8 months of software development experience\n- Career progression includes roles as a Software Engineer and Global Development Director\n- Some experience in management\n- Holds degrees from reputable universities\n- From an approved country (Colombia)', 'ai_score': 13.3}
# 0 {'candidate_id': 643479, 'rejected_reasons': [], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 0, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'N/A', 'ai_score_country': True, 'ai_summary': 'Good: Relevant education and experience in product design and management.\nBad: Lack of work experience directly related to software application development.', 'ai_score': 0}
# 65.0 {'candidate_id': 641901, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 156, 'ai_score_tech_lead': True, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good amount of experience as a software developer\n- Has experience in both individual contributor and leadership roles\n- Familiarity with modern technologies like React, JavaScript, Typescript, Docker, and .NET\n- Strong educational background with a Bachelor's degree\n- From an approved country (Mexico)", 'ai_score': 65.0}
# 25.0 {'candidate_id': 640056, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 72, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has 6 years of experience as a software developer\n- They have consistently worked as a developer\n- They have experience with modern tools and frameworks\n- The candidate is from an approved country\n- No information provided about Tech/Team Lead experience', 'ai_score': 25.0}
# 65.0 {'candidate_id': 639873, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 90, 'ai_score_tech_lead': True, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has 7+ years of software development experience and has held positions as a Senior Developer Architect and Lead Software Developer.\n- Good: They have experience with modern technologies such as Python, React, JavaScript, AWS, and Angular.\n- Good: The candidate has a strong educational background, including attending Harvard University.\n- Bad: The candidate's work experience is not exclusively focused on software development.\n- Bad: The candidate's education does not include a degree in a relevant field.", 'ai_score': 65.0}
# 24.4 {'candidate_id': 639437, 'rejected_reasons': [], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC4', 'ai_score_experience': 96, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': 'The candidate has 8 years of experience as a software developer. They have experience with modern technologies such as React, JavaScript, AngularJS, and Git. The candidate has a diverse background, having worked in various software development roles. They have a degree from Universidad Católica. The candidate is from Spain, which is one of the approved countries.', 'ai_score': 24.4}
# 4.2 {'candidate_id': 639098, 'rejected_reasons': [], 'ai_pass': 'No', 'ai_rejection_reason': 'TOO_JUNIOR', 'ai_level': 'N/A', 'ai_score_experience': 10, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has work experience as a Frontend Developer\n- The candidate is from Colombia\n- The candidate has less than 2 years of total hands-on software development experience\n- No information provided about tech/team lead or management experience\n- The candidate has experience with modern frontend technologies', 'ai_score': 4.2}
#     candidate_id rejected_reasons ai_pass ai_rejection_reason ai_level  \
# 0         650789               []     Yes                 N/A      IC4
# 1         650124               []     Yes                 N/A      IC2
# 2         649626               []     Yes                 N/A      IC3
# 3         648288               []     Yes                 N/A      IC4
# 4         648034               []     Yes                 N/A      IC3
# 5         647493               []     Yes                 N/A      N/A
# 6         647124               []     Yes                 N/A      IC3
# 7         645953               []     Yes                 N/A      N/A
# 8         644944               []     Yes                 N/A      IC4
# 9         644860               []     Yes                 N/A      IC3
# 10        644735               []     Yes                 N/A      IC4
# 11        644633               []     Yes                 N/A      IC3
# 12        644548               []     Yes                 N/A      IC4
# 13        643589               []     Yes                 N/A      IC3
# 14        643479               []      No       NOT_CORE_ROLE      N/A
# 15        641901               []     Yes                 N/A      IC4
# 16        640056               []     Yes                 N/A      IC3
# 17        639873               []     Yes                 N/A      IC4
# 18        639437               []     Yes                 N/A      IC4
# 19        639098               []      No          TOO_JUNIOR      N/A
#
#     ai_score_experience  ai_score_tech_lead ai_score_modern_tech  \
# 0                   156               False                 Many
# 1                    31               False                 Many
# 2                    48               False                 Many
# 3                   108               False                 Many
# 4                    24               False                 Many
# 5                     0               False                 None
# 6                    48               False                 Many
# 7                   228               False                 Some
# 8                    96               False                 Some
# 9                    57               False                 Many
# 10                   96               False                 Many
# 11                  156                True                 Many
# 12                  132                True                 Many
# 13                   32               False                 Many
# 14                    0               False                  N/A
# 15                  156                True                 Many
# 16                   72               False                 Many
# 17                   90                True                 Many
# 18                   96               False                 Some
# 19                   10               False                 Many
#
#     ai_score_country                                         ai_summary  \
# 0               True  Good things about this candidate:\n- Has 13 ye...
# 1               True  - Good: The candidate has relevant work experi...
# 2               True  - The candidate has 4 years of experience as a...
# 3               True  - The candidate has 9 years of work experience...
# 4               True  - Good: Two years of work experience as a soft...
# 5               True  - Good: The candidate has relevant work experi...
# 6               True  - The candidate has 4 years of experience as a...
# 7               True  - Good: The candidate has 19 years of work exp...
# 8               True  - Good: 8 years of software development experi...
# 9               True  Good things about this candidate:\n- Has 4+ ye...
# 10              True  - Good: The candidate has 8 years of work expe...
# 11              True  - Good: The candidate has 13 years of work exp...
# 12              True  The candidate has 11 years of experience as a ...
# 13              True  - Good experience with modern technologies lik...
# 14              True  Good: Relevant education and experience in pro...
# 15              True  - Good amount of experience as a software deve...
# 16              True  - The candidate has 6 years of experience as a...
# 17              True  - Good: The candidate has 7+ years of software...
# 18              True  The candidate has 8 years of experience as a s...
# 19              True  - The candidate has work experience as a Front...
#
#     ai_score
# 0       32.5
# 1        6.5
# 2       20.0
# 3       32.5
# 4       10.0
# 5        0.0
# 6       20.0
# 7       18.8
# 8       24.4
# 9       23.8
# 10      32.5
# 11      50.0
# 12      65.0
# 13      13.3
# 14       0.0
# 15      65.0
# 16      25.0
# 17      65.0
# 18      24.4
# 19       4.2

# %%
print("\n\nRunning test for 'failed' candidates...")
f_cands = read_data_from_json_file("failed_candidates.json")["data"]["candidate"]
total_f_cands = len(f_cands)
f_cand_results = process_candidates(f_cands)
print_results(f_cand_results, total_f_cands, False)
# Out:
# Running test for 'failed' candidates...
# content='1. The candidate has a total of 3 years and 8 months of work experience as a software developer. They started as a Purchasing Engineer in July 2019 and transitioned to a Project Engineer role in January 2020. Their most recent work experience is directly related to software development.\n\n2. The candidate is from Chile, which is one of the approved countries.\n\n3. The candidate has 3 years and 8 months of total hands-on software development experience, which exceeds the minimum requirement of 2 years.\n\n4. There is no information provided about the candidate\'s experience as a tech/team lead.\n\n5. There is no information provided about the candidate\'s role as an individual contributor or manager.\n\n6. The candidate has experience with modern tools and frameworks such as React, Postgres, Node, Typescript, Redux, REST API, Git, MongoDB, HTML, and CSS.\n\nBased on the evaluation, we should proceed with this candidate in the hiring process.\n\n```json\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 3 years and 8 months of work experience as a software developer.\\n- They have experience with modern tools and frameworks.\\n- The candidate is from an approved country.",\n  "level": "N/A",\n  "score_experience": 44,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has a total of 2 years and 7 months of work experience as a software developer. They have worked as a Frontend Engineer, Webshop Manager/Developer, and Freelance Developer. Their career progression has been relatively slow, with gaps between their work experiences. They have mostly worked as a developer, with some experience in management.\n\n2. Based on the criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good experience with React, JavaScript, PHP, AWS, Typescript, MySQL, Git, GraphQL, API, GitHub, Blockchain, and Microservices\\n- Has 2 years and 7 months of work experience as a software developer\\n- Worked as a Frontend Engineer, Webshop Manager/Developer, and Freelance Developer\\n- Career progression has been relatively slow\\n- Mostly worked as a developer with some management experience",\n  "level": "IC3",\n  "score_experience": 31,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has two work experiences listed. The first one is as a "PROFESSOR OF ENGLISH" from January 1, 2019, to December 31, 2021. The second one is missing a job title but is listed from January 1, 2017, to December 31, 2019. Neither of these work experiences is directly related to software application development.\n\n2. The candidate is from Spain, which is one of the approved countries.\n\n3. The candidate does not have any work experiences directly related to software development, so they do not meet the requirement of having at least 2 years of experience as a software developer.\n\n4. There is no information available about whether the candidate has tech/team lead experience.\n\n5. The candidate\'s job titles and skills indicate that they have experience with modern technologies like React, JavaScript, and CSS.\n\nBased on the evaluation above, we should reject this candidate because they do not have work experience directly related to software development.\n\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "- The candidate does not have work experience directly related to software development.\\n- The candidate has experience with modern technologies like React, JavaScript, and CSS.",\n  "level": "N/A",\n  "score_experience": 0,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# content="1. The candidate has a total of 8 years of work experience as a software developer. They started as a Wordpress Developer in 2015 and progressed to become a Web Designer & Developer, and finally a Web Developer. Their career progression has been steady, with a focus on web development using PHP, MySQL, Bootstrap, JQuery, HTML, CSS, and CodeIgniter.\n\n2. Based on the criteria, we should reject this candidate for the following reasons:\n   - Their most recent work history falls outside software development, as they have been working as a Web Developer using PHP and related technologies.\n   - The candidate is from India, which is not one of the approved countries for hiring.\n\n**Decision:** Reject\n\n**Rejection Reason:** NOT_CORE_ROLE, OUTSIDE_GEO\n\n**Summary:**\n- Good: The candidate has 8 years of experience as a software developer and has worked on web development projects using PHP, MySQL, Bootstrap, JQuery, HTML, CSS, and CodeIgniter.\n- Bad: The candidate's most recent work history is not directly related to software development, and they are not from one of the approved countries for hiring.\n\n**Level:** N/A\n\n**Score Experience:** 96 months\n\n**Score Tech Lead:** False\n\n**Score Modern Tech:** Some\n\n**Score Country:** False" additional_kwargs={} example=False
# content='1. The candidate has a total of 7 years of work experience as a software developer. They have held various positions, starting as a volunteer and then progressing to a student intern. They have experience with React, JavaScript, SQL, Java, .NET, Salesforce, HTML, CSS, and OOP.\n\n2. The candidate is from Romania, which is one of the approved countries.\n\n3. The candidate has a total of 7 years of experience as a software developer, which meets the requirement of having at least 2 years of experience.\n\n4. There is no information provided about the candidate\'s experience as a tech/team lead.\n\n5. There is no information provided about the candidate\'s role as an individual contributor or manager.\n\n6. The candidate has experience with modern tools and frameworks such as React and JavaScript.\n\nBased on the above analysis, we should proceed with this candidate in the hiring process.\n\n```json\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "Good things about this candidate:\\n- 7 years of work experience as a software developer\\n- Experience with modern tools and frameworks like React and JavaScript\\n\\nLevel: N/A\\nScore Experience: 84\\nScore Tech Lead: N/A\\nScore Modern Tech: Many\\nScore Country: True",\n  "level": "N/A",\n  "score_experience": 84,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has a total of 12 years of work experience as a software developer. They have worked in various roles such as Fullstack Developer, Web Developer, Java Developer, Frontend Developer, and Developer. Their career progression has been a mix of frontend and full stack development roles, with some experience in Java development as well.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: The candidate has 12 years of experience as a software developer.\\n- Good: They have experience in frontend, full stack, and Java development.\\n- Good: The candidate has worked with modern technologies such as React, JavaScript, Node, Angular, and MongoDB.\\n- Good: They have a bachelor\'s degree and a master\'s degree.\\n- Good: The candidate is from Colombia, which is one of the approved countries.\\n- Bad: The candidate has some employment gaps in their work history.\\n- Bad: They have limited experience as a tech/team lead.\\n- Bad: The candidate\'s education is not directly related to software development.",\n  "level": "IC3",\n  "score_experience": 144,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content="1. The candidate has a total of 2 years and 5 months of work experience as a software developer. They started as a Team Member in March 2018 and transitioned to a Software Engineer role in September 2021. Their career progression has been relatively slow, with a gap of about 3 years between their first and second software development roles. They have mostly worked as a developer, with their most recent role being a Software Engineer.\n\n2. Based on the evaluation criteria, we should reject this candidate for the following reasons:\n   - Their most recent work history falls outside software development, as their first job as a Team Member is not directly related to software application development. Rejection code: NOT_CORE_ROLE.\n   - The candidate is from the United States, which is not one of the approved countries. Rejection code: OUTSIDE_GEO.\n   - The candidate does not have at least 2 years of hands-on software development experience. Rejection code: TOO_JUNIOR.\n   - The candidate does not have any experience as a tech/team lead. Rejection code: N/A.\n   - The candidate has experience with modern technologies like JavaScript, SQL, Java, and Git, but also has experience with older technologies like Oracle and Maven. Rejection code: NOT_CORE_FOCUS.\n\n3. Rejection Reason: NOT_CORE_ROLE\n\n4. Pass: No\n\n5. Rejection Reason: NOT_CORE_ROLE\n\n6. Summary:\n   - The candidate has some relevant skills in JavaScript, SQL, Java, and Git.\n   - They have a bachelor's degree and an associate degree.\n   - However, their work experience is not directly related to software development, and they do not meet the minimum requirement of 2 years of experience.\n   - They also have experience with older technologies like Oracle and Maven, which are not in line with our focus on modern tools and frameworks.\n\n7. Level: N/A\n\n8. Score Experience: 29 (2 years and 5 months)\n\n9. Score Tech Lead: False\n\n10. Score Modern Tech: Some\n\n11. Score Country: False\n\nBased on the evaluation, we should reject this candidate." additional_kwargs={} example=False
# content="1. The candidate has a total of 2 years and 9 months of work experience as a software developer. Their career progression has been slow, starting with a beginner role and then an internship before transitioning to a non-technical role as a Junior Marketing Specialist. They also have a non-software development role as a member. Overall, their experience as a software developer is limited.\n\n2. Based on the criteria, we should reject this candidate for the following reasons:\n   - The candidate's most recent work history is not directly related to software development, as they have worked as a Junior Marketing Specialist and in non-technical roles.\n   - The candidate is from Romania, which is one of the approved countries for hiring.\n\n3. Rejection Reason: NOT_CORE_ROLE\n\n4. Summary:\n   - Limited work experience as a software developer\n   - Career progression has been slow\n   - Non-technical roles in recent work history\n\n5. Level: N/A\n\n6. Score Experience: 33 months\n\n7. Score Tech Lead: False\n\n8. Score Modern Tech: Some\n\n9. Score Country: True\n\nBased on the analysis, we should reject this candidate." additional_kwargs={} example=False
# content='1. The candidate has 2 years of work experience as a software developer. Their career progression has been slow as they have only held two positions related to software development. They have mostly worked in non-developer roles such as SEO Editor and Coordinator and Webmaster and Editor in chief.\n\n2. Based on the criteria, we should reject this candidate.\n\n**Structured Format:**\n\n```json\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "- The candidate has 2 years of work experience as a software developer.\\n- Their career progression has been slow.\\n- They have mostly worked in non-developer roles.\\n- The candidate does not meet the criteria for software application development.\\n- The candidate\'s most recent work history falls outside software development.",\n  "level": "N/A",\n  "score_experience": 24,\n  "score_tech_lead": false,\n  "score_modern_tech": "None",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has 2 years of experience as a software developer, starting from August 2021 until the present. Their career progression is not clear from the provided information, as there is only one work experience listed.\n\n2. Based on the criteria provided, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 2 years of experience as a software developer.\\n- They have experience with Python, JavaScript, SQL, Java, and other relevant technologies.\\n- The candidate holds a Bachelor\'s degree from the Military Technical Academy of Bucharest.\\n- They are currently working as a software engineer.\\n- The candidate is from Romania, which is one of the approved countries.",\n  "level": "N/A",\n  "score_experience": 24,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has one work experience as a Data Science ML Intern from June 2018 to August 2018. This experience is not directly related to software application development.\n\n2. The candidate is from Poland, which is one of the approved countries.\n\n3. The candidate has less than 2 years of total hands-on software development experience.\n\n4. There is no information about the candidate\'s tech/team lead experience.\n\n5. The candidate does have experience as an individual contributor.\n\n6. The candidate has experience with modern tools and frameworks such as Python, Java, Docker, and Django.\n\nBased on the evaluation, the candidate does not meet the criteria for proceeding in the hiring process. The rejection reason is "NOT_CORE_ROLE" since their most recent work experience is not directly related to software development.\n\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "- The candidate has less than 2 years of total hands-on software development experience.\\n- The candidate\'s most recent work experience is not directly related to software development.",\n  "level": "N/A",\n  "score_experience": 2,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 9 years of work experience as a software developer. They started as a junior developer in 2014 and then progressed to a senior developer role in 2017. They have been working as a senior developer since then, with their most recent job starting in February 2020.\n\n2. The candidate is from Spain, which is one of the approved countries.\n\n3. The candidate has more than 2 years of hands-on software development experience. They have a total of 9 years of experience as a software developer.\n\n4. There is no information provided about whether the candidate has tech/team lead experience.\n\n5. There is no information provided about whether the candidate is an individual contributor or a manager.\n\n6. The candidate has experience with modern tools and frameworks such as JavaScript, TypeScript, Jenkins, Bootstrap, jQuery, REST API, Git, Android, Spring, HTML, CSS, Maven, Microservices, GitLab, JVM, Hibernate, and SpringBoot.\n\nBased on the above analysis, we should proceed with this candidate in the hiring process.\n\n```json\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has 9 years of experience as a software developer.\\n- They have progressed from a junior developer to a senior developer role.\\n- They have experience with modern tools and frameworks.\\n- The candidate is from an approved country.",\n  "level": "IC3",\n  "score_experience": 108,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has 1 year of work experience as a software developer, based on their internship from August 2022 to August 2023. They have a Bachelor\'s degree in Computer Science, which they obtained in 2023.\n\n2. Based on the criteria:\n   - The candidate\'s work experience is directly related to software development, so they pass the first criteria.\n   - The candidate is from Romania, which is one of the approved countries, so they pass the second criteria.\n   - The candidate has 1 year of experience, which is less than the required 2 years, so they do not meet the third criteria.\n   - There is no information about the candidate having tech/team lead experience, so they do not meet the fourth criteria.\n   - There is no information about the candidate being a manager, so this criteria is not applicable.\n   - The candidate has experience with JavaScript, Node, Java, MongoDB, HTML, and Express.js, which includes modern tools and frameworks, so they pass the sixth criteria.\n\n3. Based on the evaluation above, we should reject this candidate due to not meeting the minimum required experience of 2 years.\n\n{\n  "pass_": "No",\n  "rejection_reason": "TOO_JUNIOR",\n  "summary": "The candidate does not meet the minimum required experience of 2 years as a software developer. They have 1 year of experience as an intern and a Bachelor\'s degree in Computer Science. While they have experience with modern tools and frameworks, it is not sufficient to proceed with the hiring process.",\n  "level": "N/A",\n  "score_experience": 12,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has one work experience as an Inside Sales Associate, which is not directly related to software application development. They have a Master\'s degree in a relevant field and some skills in JavaScript, Git, Linux, HTML, and CSS.\n\n2. The candidate is from Romania, which is one of the approved countries.\n\n3. The candidate has less than 2 years of total hands-on software development experience.\n\n4. The candidate does not have any tech/team lead experience.\n\n5. The candidate is not a manager.\n\n6. The candidate has some technology skills related to software development, including JavaScript, Git, Linux, HTML, and CSS. However, they do not have experience with modern tools and frameworks like Ruby, Django, AWS, Typescript, Docker, Node, React, JQuery, Python, Angular, .NET, or Java.\n\nBased on the evaluation, we should reject this candidate.\n\n{\n  "pass_": "No",\n  "rejection_reason": "TOO_JUNIOR",\n  "summary": "- The candidate has less than 2 years of software development experience.\\n- They do not have experience with modern tools and frameworks.\\n- Their work experience is not directly related to software development.",\n  "level": "N/A",\n  "score_experience": 9,\n  "score_tech_lead": false,\n  "score_modern_tech": "None",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a diverse work history with experience in technical support, teaching, content management, content writing, virtual tour moderation, and operations management. They also have experience as a founder and general manager. Their most recent work history is in technical support, which is not directly related to software development.\n\n2. The candidate is from the United States, which is not one of the approved countries for hiring.\n\n3. Based on the candidate\'s work experiences, their total years of experience as a software developer is 0. They do not have any work experience directly related to software development.\n\n4. There is no information available about whether the candidate has tech/team lead experience.\n\n5. The candidate does not have a senior management role, so this criterion is not applicable.\n\n6. The candidate\'s skills are focused on UI/UX, Sketch, and Figma, which are relevant to frontend development but not comprehensive enough to meet the criteria of working with modern tools and frameworks.\n\nBased on the evaluation above, the candidate should be rejected.\n\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "- The candidate\'s most recent work history is not directly related to software development.\\n- The candidate is not from one of the approved countries for hiring.\\n- The candidate does not have any work experience directly related to software development.\\n- The candidate\'s skills are focused on UI/UX, Sketch, and Figma, which are not comprehensive enough to meet the criteria of working with modern tools and frameworks.",\n  "level": "N/A",\n  "score_experience": 0,\n  "score_tech_lead": false,\n  "score_modern_tech": "None",\n  "score_country": false\n}' additional_kwargs={} example=False
# content='1. The candidate has two work experiences listed. The first is a web developer internship from September 2022 to July 2023, and the second is an internship in Kigali, Rwanda from July 2023 to August 2023. The candidate also has two education entries, with a bachelor\'s degree from the University of Brighton from 2019 to 2022 and two other degrees from Laude San Pedro International College from 2017 to 2019.\n\n2. Based on the criteria:\n   - The candidate has work experience directly related to software application development, so they pass the first criteria.\n   - The candidate is from Spain, which is one of the approved countries, so they pass the second criteria.\n   - The candidate has less than 2 years of total hands-on software development experience, so they do not meet the third criteria.\n   - There is no information provided about the candidate\'s tech/team lead experience, so we cannot determine if they meet the fourth criteria.\n   - The candidate does not have a senior management role, so the fifth criteria is not applicable.\n   - The candidate has experience with PHP, Java, HTML, CSS, and SQL, which are modern technologies, so they pass the sixth criteria.\n\n3. Based on the evaluation above, we should reject this candidate due to not meeting the minimum requirement of 2 years of software development experience.\n\n{\n  "pass_": "No",\n  "rejection_reason": "TOO_JUNIOR",\n  "summary": "- The candidate has work experience directly related to software application development.\\n- The candidate is from an approved country.\\n- The candidate does not meet the minimum requirement of 2 years of software development experience.",\n  "level": "N/A",\n  "score_experience": 10,\n  "score_tech_lead": false,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has two work experiences related to software development. They started as an ERP Intern Developer in November 2021 and worked until November 2022. After that, they became a PHP/JS Web Developer starting in March 2023, and the end date is missing, indicating that they are currently in this role. Their career progression shows that they have leveled up from an intern to a web developer role.\n\n2. Based on the criteria:\n   - The candidate has work experience directly related to software application development, so they pass the first criteria.\n   - The candidate is from Poland, which is one of the approved countries, so they pass the second criteria.\n   - The candidate has at least 2 years of total hands-on software development experience, so they pass the third criteria.\n   - There is no information about whether the candidate has tech/team lead experience, so this criteria is inconclusive.\n   - The candidate is not a senior manager, so they pass the fifth criteria.\n   - The candidate has experience with modern tools and frameworks like React, JavaScript, Docker, and Laravel, so they pass the sixth criteria.\n\nBased on the above analysis, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- The candidate has relevant work experience in software development.\\n- They have progressed from an intern to a web developer role.\\n- They have experience with modern tools and frameworks like React, JavaScript, Docker, and Laravel.",\n  "level": "N/A",\n  "score_experience": 20,\n  "score_tech_lead": null,\n  "score_modern_tech": "Many",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 2 years and 4 months of work experience as a software developer. They started as a Team Leader Export Documentation Administrator from May 2019 to March 2021, which is a non-software development role. After that, they worked as a Software QA Engineer from April 2021 to the present, which is a software development role. They also have a previous job from November 2015 to May 2017, but the job title is missing.\n\n2. Based on the criteria, we should reject this candidate for the following reasons:\n- Their most recent work history includes a non-software development role as a Team Leader Export Documentation Administrator.\n- The candidate is from Romania, which is an approved country.\n\n3. Rejection Reason: NOT_CORE_ROLE\n\n4. Summary:\n- The candidate has some experience as a software developer, but their most recent work history is not directly related to software development.\n- They have experience in Java, MySQL, API, Postman, and Jira.\n- The candidate has a degree from the University Politehnica of Bucharest.\n\n5. Level: N/A\n\n6. Score Experience: 28 months\n\n7. Score Tech Lead: False\n\n8. Score Modern Tech: Some\n\n9. Score Country: True\n\n**Note:** The candidate\'s work history does not meet the criteria for software development experience, and they are not from an approved country. Therefore, we should reject this candidate.\n\nOutput:\n```json\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "The candidate has some experience as a software developer, but their most recent work history is not directly related to software development. They have experience in Java, MySQL, API, Postman, and Jira. The candidate has a degree from the University Politehnica of Bucharest.",\n  "level": "N/A",\n  "score_experience": 28,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}\n```' additional_kwargs={} example=False
# content='1. The candidate has a total of 7 years of work experience. However, their work experience is not directly related to software application development. They have worked as a Designer and Graphic Designer, which are not core roles in software development.\n\n2. The candidate is from Romania, which is one of the approved countries for hiring.\n\n3. The candidate does not have any work experience directly related to software development, so they do not meet the requirement of having at least 2 years of hands-on software development experience.\n\n4. There is no information available about the candidate\'s experience as a tech/team lead.\n\n5. The candidate\'s job titles and skills indicate that they have experience with JavaScript and Java, which are modern programming languages. However, they also have experience with Adobe, which is not directly related to software development.\n\nBased on the above analysis, we should reject this candidate.\n\n```\n{\n  "pass_": "No",\n  "rejection_reason": "NOT_CORE_ROLE",\n  "summary": "- The candidate does not have work experience directly related to software application development.\\n- They have worked as a Designer and Graphic Designer, which are not core roles in software development.\\n- They have some experience with modern programming languages like JavaScript and Java, but also have experience with Adobe, which is not directly related to software development.",\n  "level": "N/A",\n  "score_experience": 84,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# content='1. The candidate has a total of 4 months of work experience as a software developer. Their career progression has been slow, with only a few short-term positions. They have worked as a Full Stack Developer and a Front End Developer Consultant.\n\n2. Based on the criteria, we should proceed with this candidate in the hiring process.\n\n{\n  "pass_": "Yes",\n  "rejection_reason": "N/A",\n  "summary": "- Good: Has experience with modern technologies like React, JavaScript, Typescript, Docker, and Redux.\\n- Good: Has worked as a Full Stack Developer and a Front End Developer Consultant.\\n- Bad: Limited work experience as a software developer, with only 4 months of experience.\\n- Bad: Slow career progression with short-term positions.\\n- Bad: No tech/team lead experience.\\n- Bad: Limited education information.",\n  "level": "N/A",\n  "score_experience": 4,\n  "score_tech_lead": false,\n  "score_modern_tech": "Some",\n  "score_country": true\n}' additional_kwargs={} example=False
# Total AI Passes: 8
# Total AI Fails: 12
# Total AI Unknowns: 0
# Percentage AI accuracy: 60.0 %
#
# Test Results - Scored Approach
# Total AI Passing Scores: 13
# Total AI Failing Scores: 7
# Total AI Unknowns: 0
# Percentage AI accuracy combined: 35.0 %
#
# Test API Consumption
# Number of tokens used for the test: 39056
# Cost for the test: 0.061661999999999995 USD
#
# Raw Data
# 18.3 {'candidate_id': 651220, 'rejected_reasons': ['NOT_CORE_ROLE'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 44, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': 'The candidate has 3 years and 8 months of work experience as a software developer. They have experience with modern tools and frameworks. The candidate is from an approved country.', 'ai_score': 18.3}
# 12.9 {'candidate_id': 651212, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 31, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- Good experience with React, JavaScript, PHP, AWS, Typescript, MySQL, Git, GraphQL, API, GitHub, Blockchain, and Microservices\n- Has 2 years and 7 months of work experience as a software developer\n- Worked as a Frontend Engineer, Webshop Manager/Developer, and Freelance Developer\n- Career progression has been relatively slow\n- Mostly worked as a developer with some management experience', 'ai_score': 12.9}
# 0.0 {'candidate_id': 651210, 'rejected_reasons': ['NOT_CORE_ROLE'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 0, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': '- The candidate does not have work experience directly related to software development.\n- The candidate has experience with modern technologies like React, JavaScript, and CSS.', 'ai_score': 0.0}
# 1.9 {'candidate_id': 651200, 'rejected_reasons': ['OUTSIDE_GEO'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE, OUTSIDE_GEO', 'ai_level': 'N/A', 'ai_score_experience': 96, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': False, 'ai_summary': "Good: The candidate has 8 years of experience as a software developer and has worked on web development projects using PHP, MySQL, Bootstrap, JQuery, HTML, CSS, and CodeIgniter. Bad: The candidate's most recent work history is not directly related to software development, and they are not from one of the approved countries for hiring.", 'ai_score': 1.9}
# 25.0 {'candidate_id': 651027, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 84, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': 'Good things about this candidate:\n- 7 years of work experience as a software developer\n- Experience with modern tools and frameworks like React and JavaScript\n\nLevel: N/A\nScore Experience: 84\nScore Tech Lead: False\nScore Modern Tech: Many\nScore Country: True', 'ai_score': 25.0}
# 25.0 {'candidate_id': 650999, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 144, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- Good: The candidate has 12 years of experience as a software developer.\n- Good: They have experience in frontend, full stack, and Java development.\n- Good: The candidate has worked with modern technologies such as React, JavaScript, Node, Angular, and MongoDB.\n- Good: They have a bachelor's degree and a master's degree.\n- Good: The candidate is from Colombia, which is one of the approved countries.\n- Bad: The candidate has some employment gaps in their work history.\n- Bad: They have limited experience as a tech/team lead.\n- Bad: The candidate's education is not directly related to software development.", 'ai_score': 25.0}
# 0.9 {'candidate_id': 650964, 'rejected_reasons': ['OUTSIDE_GEO'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 29, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': False, 'ai_summary': 'The candidate has a total of 2 years and 5 months of work experience as a software developer. They started as a Team Member in March 2018 and transitioned to a Software Engineer role in September 2021. Their career progression has been relatively slow, with a gap of about 3 years between their first and second software development roles. They have mostly worked as a developer, with their most recent role being a Software Engineer.', 'ai_score': 0.9}
# 10.3 {'candidate_id': 650845, 'rejected_reasons': ['NOT_CORE_ROLE'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 33, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': 'Limited work experience as a software developer\nCareer progression has been slow\nNon-technical roles in recent work history', 'ai_score': 10.3}
# 4.0 {'candidate_id': 650809, 'rejected_reasons': ['NOT_CORE_ROLE'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 24, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'None', 'ai_score_country': True, 'ai_summary': "- The candidate has 2 years of work experience as a software developer.\n- Their career progression has been slow.\n- They have mostly worked in non-developer roles.\n- The candidate does not meet the criteria for software application development.\n- The candidate's most recent work history falls outside software development.", 'ai_score': 4.0}
# 7.5 {'candidate_id': 650798, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 24, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': "- The candidate has 2 years of experience as a software developer.\n- They have experience with Python, JavaScript, SQL, Java, and other relevant technologies.\n- The candidate holds a Bachelor's degree from the Military Technical Academy of Bucharest.\n- They are currently working as a software engineer.\n- The candidate is from Romania, which is one of the approved countries.", 'ai_score': 7.5}
# 0 {'candidate_id': 650783, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 0, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': "- The candidate has less than 2 years of total hands-on software development experience.\n- The candidate's most recent work experience is not directly related to software development.", 'ai_score': 0}
# 25.0 {'candidate_id': 650771, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'IC3', 'ai_score_experience': 108, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': 'The candidate has 9 years of experience as a software developer. They have progressed from a junior developer to a senior developer role. They have experience with modern tools and frameworks. The candidate is from an approved country.', 'ai_score': 25.0}
# 3.8 {'candidate_id': 650743, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'No', 'ai_rejection_reason': 'TOO_JUNIOR', 'ai_level': 'N/A', 'ai_score_experience': 12, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': "The candidate does not meet the minimum required experience of 2 years as a software developer. They have 1 year of experience as an intern and a Bachelor's degree in Computer Science. While they have experience with modern tools and frameworks, it is not sufficient to proceed with the hiring process.", 'ai_score': 3.8}
# 1.5 {'candidate_id': 650736, 'rejected_reasons': ['NOT_CORE_ROLE'], 'ai_pass': 'No', 'ai_rejection_reason': 'TOO_JUNIOR', 'ai_level': 'N/A', 'ai_score_experience': 9, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'None', 'ai_score_country': True, 'ai_summary': '- The candidate has less than 2 years of software development experience.\n- They do not have experience with modern tools and frameworks.\n- Their work experience is not directly related to software development.', 'ai_score': 1.5}
# 0.0 {'candidate_id': 650732, 'rejected_reasons': ['OUTSIDE_GEO'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 0, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'None', 'ai_score_country': False, 'ai_summary': "- The candidate's most recent work history is not directly related to software development.\n- The candidate is not from one of the approved countries for hiring.\n- The candidate does not have any work experience directly related to software development.\n- The candidate's skills are focused on UI/UX, Sketch, and Figma, which are not comprehensive enough to meet the criteria of working with modern tools and frameworks.", 'ai_score': 0.0}
# 4.2 {'candidate_id': 650728, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'No', 'ai_rejection_reason': 'TOO_JUNIOR', 'ai_level': 'N/A', 'ai_score_experience': 10, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has work experience directly related to software application development.\n- The candidate is from an approved country.\n- The candidate does not meet the minimum requirement of 2 years of software development experience.', 'ai_score': 4.2}
# 8.3 {'candidate_id': 650686, 'rejected_reasons': ['TOO_JUNIOR'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 20, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Many', 'ai_score_country': True, 'ai_summary': '- The candidate has relevant work experience in software development.\n- They have progressed from an intern to a web developer role.\n- They have experience with modern tools and frameworks like React, JavaScript, Docker, and Laravel.', 'ai_score': 8.3}
# 8.8 {'candidate_id': 650667, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 28, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': 'The candidate has some experience as a software developer, but their most recent work history is not directly related to software development. They have experience in Java, MySQL, API, Postman, and Jira. The candidate has a degree from the University Politehnica of Bucharest.', 'ai_score': 8.8}
# 18.8 {'candidate_id': 650658, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'No', 'ai_rejection_reason': 'NOT_CORE_ROLE', 'ai_level': 'N/A', 'ai_score_experience': 84, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': '- The candidate does not have work experience directly related to software application development.\n- They have worked as a Designer and Graphic Designer, which are not core roles in software development.\n- They have some experience with modern programming languages like JavaScript and Java, but also have experience with Adobe, which is not directly related to software development.', 'ai_score': 18.8}
# 1.2 {'candidate_id': 650584, 'rejected_reasons': ['NOT_CORE_FOCUS'], 'ai_pass': 'Yes', 'ai_rejection_reason': 'N/A', 'ai_level': 'N/A', 'ai_score_experience': 4, 'ai_score_tech_lead': False, 'ai_score_modern_tech': 'Some', 'ai_score_country': True, 'ai_summary': '- Good: Has experience with modern technologies like React, JavaScript, Typescript, Docker, and Redux.\n- Good: Has worked as a Full Stack Developer and a Front End Developer Consultant.\n- Bad: Limited work experience as a software developer, with only 4 months of experience.\n- Bad: Slow career progression with short-term positions.\n- Bad: No tech/team lead experience.\n- Bad: Limited education information.', 'ai_score': 1.2}
#     candidate_id  rejected_reasons ai_pass         ai_rejection_reason  \
# 0         651220   [NOT_CORE_ROLE]     Yes                         N/A
# 1         651212      [TOO_JUNIOR]     Yes                         N/A
# 2         651210   [NOT_CORE_ROLE]      No               NOT_CORE_ROLE
# 3         651200     [OUTSIDE_GEO]      No  NOT_CORE_ROLE, OUTSIDE_GEO
# 4         651027      [TOO_JUNIOR]     Yes                         N/A
# 5         650999  [NOT_CORE_FOCUS]     Yes                         N/A
# 6         650964     [OUTSIDE_GEO]      No               NOT_CORE_ROLE
# 7         650845   [NOT_CORE_ROLE]      No               NOT_CORE_ROLE
# 8         650809   [NOT_CORE_ROLE]      No               NOT_CORE_ROLE
# 9         650798  [NOT_CORE_FOCUS]     Yes                         N/A
# 10        650783      [TOO_JUNIOR]      No               NOT_CORE_ROLE
# 11        650771  [NOT_CORE_FOCUS]     Yes                         N/A
# 12        650743      [TOO_JUNIOR]      No                  TOO_JUNIOR
# 13        650736   [NOT_CORE_ROLE]      No                  TOO_JUNIOR
# 14        650732     [OUTSIDE_GEO]      No               NOT_CORE_ROLE
# 15        650728      [TOO_JUNIOR]      No                  TOO_JUNIOR
# 16        650686      [TOO_JUNIOR]     Yes                         N/A
# 17        650667  [NOT_CORE_FOCUS]      No               NOT_CORE_ROLE
# 18        650658  [NOT_CORE_FOCUS]      No               NOT_CORE_ROLE
# 19        650584  [NOT_CORE_FOCUS]     Yes                         N/A
#
#    ai_level  ai_score_experience  ai_score_tech_lead ai_score_modern_tech  \
# 0       N/A                   44               False                 Many
# 1       IC3                   31               False                 Many
# 2       N/A                    0               False                 Some
# 3       N/A                   96               False                 Some
# 4       N/A                   84               False                 Many
# 5       IC3                  144               False                 Many
# 6       N/A                   29               False                 Some
# 7       N/A                   33               False                 Some
# 8       N/A                   24               False                 None
# 9       N/A                   24               False                 Some
# 10      N/A                    0               False                 Many
# 11      IC3                  108               False                 Many
# 12      N/A                   12               False                 Some
# 13      N/A                    9               False                 None
# 14      N/A                    0               False                 None
# 15      N/A                   10               False                 Many
# 16      N/A                   20               False                 Many
# 17      N/A                   28               False                 Some
# 18      N/A                   84               False                 Some
# 19      N/A                    4               False                 Some
#
#     ai_score_country                                         ai_summary  \
# 0               True  The candidate has 3 years and 8 months of work...
# 1               True  - Good experience with React, JavaScript, PHP,...
# 2               True  - The candidate does not have work experience ...
# 3              False  Good: The candidate has 8 years of experience ...
# 4               True  Good things about this candidate:\n- 7 years o...
# 5               True  - Good: The candidate has 12 years of experien...
# 6              False  The candidate has a total of 2 years and 5 mon...
# 7               True  Limited work experience as a software develope...
# 8               True  - The candidate has 2 years of work experience...
# 9               True  - The candidate has 2 years of experience as a...
# 10              True  - The candidate has less than 2 years of total...
# 11              True  The candidate has 9 years of experience as a s...
# 12              True  The candidate does not meet the minimum requir...
# 13              True  - The candidate has less than 2 years of softw...
# 14             False  - The candidate's most recent work history is ...
# 15              True  - The candidate has work experience directly r...
# 16              True  - The candidate has relevant work experience i...
# 17              True  The candidate has some experience as a softwar...
# 18              True  - The candidate does not have work experience ...
# 19              True  - Good: Has experience with modern technologie...
#
#     ai_score
# 0       18.3
# 1       12.9
# 2        0.0
# 3        1.9
# 4       25.0
# 5       25.0
# 6        0.9
# 7       10.3
# 8        4.0
# 9        7.5
# 10       0.0
# 11      25.0
# 12       3.8
# 13       1.5
# 14       0.0
# 15       4.2
# 16       8.3
# 17       8.8
# 18      18.8
# 19       1.2
